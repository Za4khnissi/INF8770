# %%
import numpy as np
import math
from anytree import Node, RenderTree, PreOrderIter, AsciiStyle

# %%
text_number = input("Quel texte voulez-vous lire ? (entrez un num entre 1 et 5) : ")

file_name = f"textes/texte_{text_number}.txt"
Message = open(file_name, "r").read()

print(Message)
# Out:
# Aliquam placerat dictum lectus vel pellentesque. Vestibulum semper dui lacus, sed commodo dolor maximus a. Praesent convallis in quam in posuere. Ut eleifend tortor a laoreet imperdiet. Sed pharetra risus sit amet velit cursus semper. Nam congue ac lectus sit amet laoreet. Integer quis lacinia turpis. Maecenas erat orci, porttitor ac ligula dapibus, interdum fringilla nunc. Proin auctor, arcu ac fermentum ultricies, erat justo laoreet nunc, sit amet lacinia lorem elit vel dolor. Aenean fermentum, mi sed iaculis laoreet, mauris nibh accumsan mauris, imperdiet pretium dui enim sit amet massa. Quisque sit amet tristique eros, eget lacinia tellus. Nam quis risus maximus, laoreet felis sit amet, efficitur neque. In pharetra urna at erat facilisis lobortis a eu orci.Donec suscipit, mi et porttitor ullamcorper, dui nisi mollis tortor, a facilisis elit enim ut metus. Cras sed dui sit amet metus sodales pretium at vitae magna. Donec ut efficitur leo, sit amet malesuada arcu. Mauris viverra viverra semper. Nam finibus ut sapien feugiat porttitor. Sed ornare laoreet libero ac semper. Ut vehicula luctus dui. Suspendisse ultrices luctus erat, in iaculis velit ultrices sit amet. Nulla a pulvinar ligula. Nulla at diam maximus, dignissim sapien dignissim, malesuada nulla. Proin in dui finibus, finibus nisl id, vehicula mauris.

# %%
#Liste qui sera modifié jusqu'à ce qu'elle contienne seulement la racine de l'arbre
ArbreSymb =[[Message[0], Message.count(Message[0]), Node(Message[0])]]
#dictionnaire obtenu à partir de l'arbre.
dictionnaire = [[Message[0], '']]
nbsymboles = 1

#Recherche des feuilles de l'arbre
for i in range(1,len(Message)):
    if not list(filter(lambda x: x[0] == Message[i], ArbreSymb)):
        ArbreSymb += [[Message[i], Message.count(Message[i]),Node(Message[i])]]
        dictionnaire += [[Message[i], '']]
        nbsymboles += 1

longueurOriginale = np.ceil(np.log2(nbsymboles))*len(Message)

OccSymb = ArbreSymb.copy()

# %%
ArbreSymb = sorted(ArbreSymb, key=lambda x: x[1])
print(ArbreSymb)
# Out:
# [['V', 1, Node('/V')], ['j', 1, Node('/j')], ['Q', 1, Node('/Q')], ['C', 1, Node('/C')], ['A', 2, Node('/A')], ['U', 2, Node('/U')], ['I', 2, Node('/I')], ['M', 2, Node('/M')], ['D', 2, Node('/D')], ['x', 3, Node('/x')], ['P', 3, Node('/P')], ['S', 3, Node('/S')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]

# %%
while len(ArbreSymb) > 1:
    #Fusion des noeuds de poids plus faibles
    symbfusionnes = ArbreSymb[0][0] + ArbreSymb[1][0]
    #Création d'un nouveau noeud
    noeud = Node(symbfusionnes)
    temp = [symbfusionnes, ArbreSymb[0][1] + ArbreSymb[1][1], noeud]
    #Ajustement de l'arbre pour connecter le nouveau avec ses parents
    ArbreSymb[0][2].parent = noeud
    ArbreSymb[1][2].parent = noeud
    #Enlève les noeuds fusionnés de la liste de noeud à fusionner.
    del ArbreSymb[0:2]
    #Ajout du nouveau noeud à la liste et tri.
    ArbreSymb += [temp]
    #Pour affichage de l'arbre ou des sous-branches
    print('\nArbre actuel:\n\n')
    for i in range(len(ArbreSymb)):
        if len(ArbreSymb[i][0]) > 1:
            print(RenderTree(ArbreSymb[i][2], style=AsciiStyle()).by_attr())
    ArbreSymb = sorted(ArbreSymb, key=lambda x: x[1])
    print(ArbreSymb)
# Out:
# Arbre actuel:
#
#
# Vj
# |-- V
# +-- j
# [['Q', 1, Node('/Q')], ['C', 1, Node('/C')], ['A', 2, Node('/A')], ['U', 2, Node('/U')], ['I', 2, Node('/I')], ['M', 2, Node('/M')], ['D', 2, Node('/D')], ['Vj', 2, Node('/Vj')], ['x', 3, Node('/x')], ['P', 3, Node('/P')], ['S', 3, Node('/S')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# Vj
# |-- V
# +-- j
# QC
# |-- Q
# +-- C
# [['A', 2, Node('/A')], ['U', 2, Node('/U')], ['I', 2, Node('/I')], ['M', 2, Node('/M')], ['D', 2, Node('/D')], ['Vj', 2, Node('/Vj')], ['QC', 2, Node('/QC')], ['x', 3, Node('/x')], ['P', 3, Node('/P')], ['S', 3, Node('/S')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# Vj
# |-- V
# +-- j
# QC
# |-- Q
# +-- C
# AU
# |-- A
# +-- U
# [['I', 2, Node('/I')], ['M', 2, Node('/M')], ['D', 2, Node('/D')], ['Vj', 2, Node('/Vj')], ['QC', 2, Node('/QC')], ['x', 3, Node('/x')], ['P', 3, Node('/P')], ['S', 3, Node('/S')], ['AU', 4, Node('/AU')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# Vj
# |-- V
# +-- j
# QC
# |-- Q
# +-- C
# AU
# |-- A
# +-- U
# IM
# |-- I
# +-- M
# [['D', 2, Node('/D')], ['Vj', 2, Node('/Vj')], ['QC', 2, Node('/QC')], ['x', 3, Node('/x')], ['P', 3, Node('/P')], ['S', 3, Node('/S')], ['AU', 4, Node('/AU')], ['IM', 4, Node('/IM')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# QC
# |-- Q
# +-- C
# AU
# |-- A
# +-- U
# IM
# |-- I
# +-- M
# DVj
# |-- D
# +-- Vj
#     |-- V
#     +-- j
# [['QC', 2, Node('/QC')], ['x', 3, Node('/x')], ['P', 3, Node('/P')], ['S', 3, Node('/S')], ['AU', 4, Node('/AU')], ['IM', 4, Node('/IM')], ['DVj', 4, Node('/DVj')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# AU
# |-- A
# +-- U
# IM
# |-- I
# +-- M
# DVj
# |-- D
# +-- Vj
#     |-- V
#     +-- j
# QCx
# |-- QC
# |   |-- Q
# |   +-- C
# +-- x
# [['P', 3, Node('/P')], ['S', 3, Node('/S')], ['AU', 4, Node('/AU')], ['IM', 4, Node('/IM')], ['DVj', 4, Node('/DVj')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['QCx', 5, Node('/QCx')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# AU
# |-- A
# +-- U
# IM
# |-- I
# +-- M
# DVj
# |-- D
# +-- Vj
#     |-- V
#     +-- j
# QCx
# |-- QC
# |   |-- Q
# |   +-- C
# +-- x
# PS
# |-- P
# +-- S
# [['AU', 4, Node('/AU')], ['IM', 4, Node('/IM')], ['DVj', 4, Node('/DVj')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['QCx', 5, Node('/QCx')], ['PS', 6, Node('/PS')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# DVj
# |-- D
# +-- Vj
#     |-- V
#     +-- j
# QCx
# |-- QC
# |   |-- Q
# |   +-- C
# +-- x
# PS
# |-- P
# +-- S
# AUIM
# |-- AU
# |   |-- A
# |   +-- U
# +-- IM
#     |-- I
#     +-- M
# [['DVj', 4, Node('/DVj')], ['h', 5, Node('/h')], ['N', 5, Node('/N')], ['QCx', 5, Node('/QCx')], ['PS', 6, Node('/PS')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['AUIM', 8, Node('/AUIM')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# QCx
# |-- QC
# |   |-- Q
# |   +-- C
# +-- x
# PS
# |-- P
# +-- S
# AUIM
# |-- AU
# |   |-- A
# |   +-- U
# +-- IM
#     |-- I
#     +-- M
# DVjh
# |-- DVj
# |   |-- D
# |   +-- Vj
# |       |-- V
# |       +-- j
# +-- h
# [['N', 5, Node('/N')], ['QCx', 5, Node('/QCx')], ['PS', 6, Node('/PS')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['AUIM', 8, Node('/AUIM')], ['DVjh', 9, Node('/DVjh')], ['g', 10, Node('/g')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# PS
# |-- P
# +-- S
# AUIM
# |-- AU
# |   |-- A
# |   +-- U
# +-- IM
#     |-- I
#     +-- M
# DVjh
# |-- DVj
# |   |-- D
# |   +-- Vj
# |       |-- V
# |       +-- j
# +-- h
# NQCx
# |-- N
# +-- QCx
#     |-- QC
#     |   |-- Q
#     |   +-- C
#     +-- x
# [['PS', 6, Node('/PS')], ['q', 8, Node('/q')], ['b', 8, Node('/b')], ['AUIM', 8, Node('/AUIM')], ['DVjh', 9, Node('/DVjh')], ['g', 10, Node('/g')], ['NQCx', 10, Node('/NQCx')], ['v', 13, Node('/v')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# AUIM
# |-- AU
# |   |-- A
# |   +-- U
# +-- IM
#     |-- I
#     +-- M
# DVjh
# |-- DVj
# |   |-- D
# |   +-- Vj
# |       |-- V
# |       +-- j
# +-- h
# NQCx
# |-- N
# +-- QCx
#     |-- QC
#     |   |-- Q
#     |   +-- C
#     +-- x
# PSq
# |-- PS
# |   |-- P
# |   +-- S
# +-- q
# [['b', 8, Node('/b')], ['AUIM', 8, Node('/AUIM')], ['DVjh', 9, Node('/DVjh')], ['g', 10, Node('/g')], ['NQCx', 10, Node('/NQCx')], ['v', 13, Node('/v')], ['PSq', 14, Node('/PSq')], ['f', 15, Node('/f')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# DVjh
# |-- DVj
# |   |-- D
# |   +-- Vj
# |       |-- V
# |       +-- j
# +-- h
# NQCx
# |-- N
# +-- QCx
#     |-- QC
#     |   |-- Q
#     |   +-- C
#     +-- x
# PSq
# |-- PS
# |   |-- P
# |   +-- S
# +-- q
# bAUIM
# |-- b
# +-- AUIM
#     |-- AU
#     |   |-- A
#     |   +-- U
#     +-- IM
#         |-- I
#         +-- M
# [['DVjh', 9, Node('/DVjh')], ['g', 10, Node('/g')], ['NQCx', 10, Node('/NQCx')], ['v', 13, Node('/v')], ['PSq', 14, Node('/PSq')], ['f', 15, Node('/f')], ['bAUIM', 16, Node('/bAUIM')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# NQCx
# |-- N
# +-- QCx
#     |-- QC
#     |   |-- Q
#     |   +-- C
#     +-- x
# PSq
# |-- PS
# |   |-- P
# |   +-- S
# +-- q
# bAUIM
# |-- b
# +-- AUIM
#     |-- AU
#     |   |-- A
#     |   +-- U
#     +-- IM
#         |-- I
#         +-- M
# DVjhg
# |-- DVjh
# |   |-- DVj
# |   |   |-- D
# |   |   +-- Vj
# |   |       |-- V
# |   |       +-- j
# |   +-- h
# +-- g
# [['NQCx', 10, Node('/NQCx')], ['v', 13, Node('/v')], ['PSq', 14, Node('/PSq')], ['f', 15, Node('/f')], ['bAUIM', 16, Node('/bAUIM')], ['DVjhg', 19, Node('/DVjhg')], [',', 21, Node('/,')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# PSq
# |-- PS
# |   |-- P
# |   +-- S
# +-- q
# bAUIM
# |-- b
# +-- AUIM
#     |-- AU
#     |   |-- A
#     |   +-- U
#     +-- IM
#         |-- I
#         +-- M
# DVjhg
# |-- DVjh
# |   |-- DVj
# |   |   |-- D
# |   |   +-- Vj
# |   |       |-- V
# |   |       +-- j
# |   +-- h
# +-- g
# NQCxv
# |-- NQCx
# |   |-- N
# |   +-- QCx
# |       |-- QC
# |       |   |-- Q
# |       |   +-- C
# |       +-- x
# +-- v
# [['PSq', 14, Node('/PSq')], ['f', 15, Node('/f')], ['bAUIM', 16, Node('/bAUIM')], ['DVjhg', 19, Node('/DVjhg')], [',', 21, Node('/,')], ['NQCxv', 23, Node('/NQCxv')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# bAUIM
# |-- b
# +-- AUIM
#     |-- AU
#     |   |-- A
#     |   +-- U
#     +-- IM
#         |-- I
#         +-- M
# DVjhg
# |-- DVjh
# |   |-- DVj
# |   |   |-- D
# |   |   +-- Vj
# |   |       |-- V
# |   |       +-- j
# |   +-- h
# +-- g
# NQCxv
# |-- NQCx
# |   |-- N
# |   +-- QCx
# |       |-- QC
# |       |   |-- Q
# |       |   +-- C
# |       +-- x
# +-- v
# PSqf
# |-- PSq
# |   |-- PS
# |   |   |-- P
# |   |   +-- S
# |   +-- q
# +-- f
# [['bAUIM', 16, Node('/bAUIM')], ['DVjhg', 19, Node('/DVjhg')], [',', 21, Node('/,')], ['NQCxv', 23, Node('/NQCxv')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['PSqf', 29, Node('/PSqf')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# NQCxv
# |-- NQCx
# |   |-- N
# |   +-- QCx
# |       |-- QC
# |       |   |-- Q
# |       |   +-- C
# |       +-- x
# +-- v
# PSqf
# |-- PSq
# |   |-- PS
# |   |   |-- P
# |   |   +-- S
# |   +-- q
# +-- f
# bAUIMDVjhg
# |-- bAUIM
# |   |-- b
# |   +-- AUIM
# |       |-- AU
# |       |   |-- A
# |       |   +-- U
# |       +-- IM
# |           |-- I
# |           +-- M
# +-- DVjhg
#     |-- DVjh
#     |   |-- DVj
#     |   |   |-- D
#     |   |   +-- Vj
#     |   |       |-- V
#     |   |       +-- j
#     |   +-- h
#     +-- g
# [[',', 21, Node('/,')], ['NQCxv', 23, Node('/NQCxv')], ['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['PSqf', 29, Node('/PSqf')], ['bAUIMDVjhg', 35, Node('/bAUIMDVjhg')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# PSqf
# |-- PSq
# |   |-- PS
# |   |   |-- P
# |   |   +-- S
# |   +-- q
# +-- f
# bAUIMDVjhg
# |-- bAUIM
# |   |-- b
# |   +-- AUIM
# |       |-- AU
# |       |   |-- A
# |       |   +-- U
# |       +-- IM
# |           |-- I
# |           +-- M
# +-- DVjhg
#     |-- DVjh
#     |   |-- DVj
#     |   |   |-- D
#     |   |   +-- Vj
#     |   |       |-- V
#     |   |       +-- j
#     |   +-- h
#     +-- g
# ,NQCxv
# |-- ,
# +-- NQCxv
#     |-- NQCx
#     |   |-- N
#     |   +-- QCx
#     |       |-- QC
#     |       |   |-- Q
#     |       |   +-- C
#     |       +-- x
#     +-- v
# [['p', 24, Node('/p')], ['.', 24, Node('/.')], ['d', 28, Node('/d')], ['PSqf', 29, Node('/PSqf')], ['bAUIMDVjhg', 35, Node('/bAUIMDVjhg')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], [',NQCxv', 44, Node('/,NQCxv')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# PSqf
# |-- PSq
# |   |-- PS
# |   |   |-- P
# |   |   +-- S
# |   +-- q
# +-- f
# bAUIMDVjhg
# |-- bAUIM
# |   |-- b
# |   +-- AUIM
# |       |-- AU
# |       |   |-- A
# |       |   +-- U
# |       +-- IM
# |           |-- I
# |           +-- M
# +-- DVjhg
#     |-- DVjh
#     |   |-- DVj
#     |   |   |-- D
#     |   |   +-- Vj
#     |   |       |-- V
#     |   |       +-- j
#     |   +-- h
#     +-- g
# ,NQCxv
# |-- ,
# +-- NQCxv
#     |-- NQCx
#     |   |-- N
#     |   +-- QCx
#     |       |-- QC
#     |       |   |-- Q
#     |       |   +-- C
#     |       +-- x
#     +-- v
# p.
# |-- p
# +-- .
# [['d', 28, Node('/d')], ['PSqf', 29, Node('/PSqf')], ['bAUIMDVjhg', 35, Node('/bAUIMDVjhg')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], [',NQCxv', 44, Node('/,NQCxv')], ['p.', 48, Node('/p.')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# bAUIMDVjhg
# |-- bAUIM
# |   |-- b
# |   +-- AUIM
# |       |-- AU
# |       |   |-- A
# |       |   +-- U
# |       +-- IM
# |           |-- I
# |           +-- M
# +-- DVjhg
#     |-- DVjh
#     |   |-- DVj
#     |   |   |-- D
#     |   |   +-- Vj
#     |   |       |-- V
#     |   |       +-- j
#     |   +-- h
#     +-- g
# ,NQCxv
# |-- ,
# +-- NQCxv
#     |-- NQCx
#     |   |-- N
#     |   +-- QCx
#     |       |-- QC
#     |       |   |-- Q
#     |       |   +-- C
#     |       +-- x
#     +-- v
# p.
# |-- p
# +-- .
# dPSqf
# |-- d
# +-- PSqf
#     |-- PSq
#     |   |-- PS
#     |   |   |-- P
#     |   |   +-- S
#     |   +-- q
#     +-- f
# [['bAUIMDVjhg', 35, Node('/bAUIMDVjhg')], ['c', 43, Node('/c')], ['o', 44, Node('/o')], [',NQCxv', 44, Node('/,NQCxv')], ['p.', 48, Node('/p.')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['dPSqf', 57, Node('/dPSqf')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# ,NQCxv
# |-- ,
# +-- NQCxv
#     |-- NQCx
#     |   |-- N
#     |   +-- QCx
#     |       |-- QC
#     |       |   |-- Q
#     |       |   +-- C
#     |       +-- x
#     +-- v
# p.
# |-- p
# +-- .
# dPSqf
# |-- d
# +-- PSqf
#     |-- PSq
#     |   |-- PS
#     |   |   |-- P
#     |   |   +-- S
#     |   +-- q
#     +-- f
# bAUIMDVjhgc
# |-- bAUIMDVjhg
# |   |-- bAUIM
# |   |   |-- b
# |   |   +-- AUIM
# |   |       |-- AU
# |   |       |   |-- A
# |   |       |   +-- U
# |   |       +-- IM
# |   |           |-- I
# |   |           +-- M
# |   +-- DVjhg
# |       |-- DVjh
# |       |   |-- DVj
# |       |   |   |-- D
# |       |   |   +-- Vj
# |       |   |       |-- V
# |       |   |       +-- j
# |       |   +-- h
# |       +-- g
# +-- c
# [['o', 44, Node('/o')], [',NQCxv', 44, Node('/,NQCxv')], ['p.', 48, Node('/p.')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['dPSqf', 57, Node('/dPSqf')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['bAUIMDVjhgc', 78, Node('/bAUIMDVjhgc')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# p.
# |-- p
# +-- .
# dPSqf
# |-- d
# +-- PSqf
#     |-- PSq
#     |   |-- PS
#     |   |   |-- P
#     |   |   +-- S
#     |   +-- q
#     +-- f
# bAUIMDVjhgc
# |-- bAUIMDVjhg
# |   |-- bAUIM
# |   |   |-- b
# |   |   +-- AUIM
# |   |       |-- AU
# |   |       |   |-- A
# |   |       |   +-- U
# |   |       +-- IM
# |   |           |-- I
# |   |           +-- M
# |   +-- DVjhg
# |       |-- DVjh
# |       |   |-- DVj
# |       |   |   |-- D
# |       |   |   +-- Vj
# |       |   |       |-- V
# |       |   |       +-- j
# |       |   +-- h
# |       +-- g
# +-- c
# o,NQCxv
# |-- o
# +-- ,NQCxv
#     |-- ,
#     +-- NQCxv
#         |-- NQCx
#         |   |-- N
#         |   +-- QCx
#         |       |-- QC
#         |       |   |-- Q
#         |       |   +-- C
#         |       +-- x
#         +-- v
# [['p.', 48, Node('/p.')], ['n', 49, Node('/n')], ['m', 57, Node('/m')], ['dPSqf', 57, Node('/dPSqf')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['bAUIMDVjhgc', 78, Node('/bAUIMDVjhgc')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['o,NQCxv', 88, Node('/o,NQCxv')], ['t', 91, Node('/t')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# dPSqf
# |-- d
# +-- PSqf
#     |-- PSq
#     |   |-- PS
#     |   |   |-- P
#     |   |   +-- S
#     |   +-- q
#     +-- f
# bAUIMDVjhgc
# |-- bAUIMDVjhg
# |   |-- bAUIM
# |   |   |-- b
# |   |   +-- AUIM
# |   |       |-- AU
# |   |       |   |-- A
# |   |       |   +-- U
# |   |       +-- IM
# |   |           |-- I
# |   |           +-- M
# |   +-- DVjhg
# |       |-- DVjh
# |       |   |-- DVj
# |       |   |   |-- D
# |       |   |   +-- Vj
# |       |   |       |-- V
# |       |   |       +-- j
# |       |   +-- h
# |       +-- g
# +-- c
# o,NQCxv
# |-- o
# +-- ,NQCxv
#     |-- ,
#     +-- NQCxv
#         |-- NQCx
#         |   |-- N
#         |   +-- QCx
#         |       |-- QC
#         |       |   |-- Q
#         |       |   +-- C
#         |       +-- x
#         +-- v
# p.n
# |-- p.
# |   |-- p
# |   +-- .
# +-- n
# [['m', 57, Node('/m')], ['dPSqf', 57, Node('/dPSqf')], ['l', 67, Node('/l')], ['r', 78, Node('/r')], ['bAUIMDVjhgc', 78, Node('/bAUIMDVjhgc')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['o,NQCxv', 88, Node('/o,NQCxv')], ['t', 91, Node('/t')], ['p.n', 97, Node('/p.n')], ['a', 102, Node('/a')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# bAUIMDVjhgc
# |-- bAUIMDVjhg
# |   |-- bAUIM
# |   |   |-- b
# |   |   +-- AUIM
# |   |       |-- AU
# |   |       |   |-- A
# |   |       |   +-- U
# |   |       +-- IM
# |   |           |-- I
# |   |           +-- M
# |   +-- DVjhg
# |       |-- DVjh
# |       |   |-- DVj
# |       |   |   |-- D
# |       |   |   +-- Vj
# |       |   |       |-- V
# |       |   |       +-- j
# |       |   +-- h
# |       +-- g
# +-- c
# o,NQCxv
# |-- o
# +-- ,NQCxv
#     |-- ,
#     +-- NQCxv
#         |-- NQCx
#         |   |-- N
#         |   +-- QCx
#         |       |-- QC
#         |       |   |-- Q
#         |       |   +-- C
#         |       +-- x
#         +-- v
# p.n
# |-- p.
# |   |-- p
# |   +-- .
# +-- n
# mdPSqf
# |-- m
# +-- dPSqf
#     |-- d
#     +-- PSqf
#         |-- PSq
#         |   |-- PS
#         |   |   |-- P
#         |   |   +-- S
#         |   +-- q
#         +-- f
# [['l', 67, Node('/l')], ['r', 78, Node('/r')], ['bAUIMDVjhgc', 78, Node('/bAUIMDVjhgc')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['o,NQCxv', 88, Node('/o,NQCxv')], ['t', 91, Node('/t')], ['p.n', 97, Node('/p.n')], ['a', 102, Node('/a')], ['mdPSqf', 114, Node('/mdPSqf')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# bAUIMDVjhgc
# |-- bAUIMDVjhg
# |   |-- bAUIM
# |   |   |-- b
# |   |   +-- AUIM
# |   |       |-- AU
# |   |       |   |-- A
# |   |       |   +-- U
# |   |       +-- IM
# |   |           |-- I
# |   |           +-- M
# |   +-- DVjhg
# |       |-- DVjh
# |       |   |-- DVj
# |       |   |   |-- D
# |       |   |   +-- Vj
# |       |   |       |-- V
# |       |   |       +-- j
# |       |   +-- h
# |       +-- g
# +-- c
# o,NQCxv
# |-- o
# +-- ,NQCxv
#     |-- ,
#     +-- NQCxv
#         |-- NQCx
#         |   |-- N
#         |   +-- QCx
#         |       |-- QC
#         |       |   |-- Q
#         |       |   +-- C
#         |       +-- x
#         +-- v
# p.n
# |-- p.
# |   |-- p
# |   +-- .
# +-- n
# mdPSqf
# |-- m
# +-- dPSqf
#     |-- d
#     +-- PSqf
#         |-- PSq
#         |   |-- PS
#         |   |   |-- P
#         |   |   +-- S
#         |   +-- q
#         +-- f
# lr
# |-- l
# +-- r
# [['bAUIMDVjhgc', 78, Node('/bAUIMDVjhgc')], ['u', 84, Node('/u')], ['s', 87, Node('/s')], ['o,NQCxv', 88, Node('/o,NQCxv')], ['t', 91, Node('/t')], ['p.n', 97, Node('/p.n')], ['a', 102, Node('/a')], ['mdPSqf', 114, Node('/mdPSqf')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], ['lr', 145, Node('/lr')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# o,NQCxv
# |-- o
# +-- ,NQCxv
#     |-- ,
#     +-- NQCxv
#         |-- NQCx
#         |   |-- N
#         |   +-- QCx
#         |       |-- QC
#         |       |   |-- Q
#         |       |   +-- C
#         |       +-- x
#         +-- v
# p.n
# |-- p.
# |   |-- p
# |   +-- .
# +-- n
# mdPSqf
# |-- m
# +-- dPSqf
#     |-- d
#     +-- PSqf
#         |-- PSq
#         |   |-- PS
#         |   |   |-- P
#         |   |   +-- S
#         |   +-- q
#         +-- f
# lr
# |-- l
# +-- r
# bAUIMDVjhgcu
# |-- bAUIMDVjhgc
# |   |-- bAUIMDVjhg
# |   |   |-- bAUIM
# |   |   |   |-- b
# |   |   |   +-- AUIM
# |   |   |       |-- AU
# |   |   |       |   |-- A
# |   |   |       |   +-- U
# |   |   |       +-- IM
# |   |   |           |-- I
# |   |   |           +-- M
# |   |   +-- DVjhg
# |   |       |-- DVjh
# |   |       |   |-- DVj
# |   |       |   |   |-- D
# |   |       |   |   +-- Vj
# |   |       |   |       |-- V
# |   |       |   |       +-- j
# |   |       |   +-- h
# |   |       +-- g
# |   +-- c
# +-- u
# [['s', 87, Node('/s')], ['o,NQCxv', 88, Node('/o,NQCxv')], ['t', 91, Node('/t')], ['p.n', 97, Node('/p.n')], ['a', 102, Node('/a')], ['mdPSqf', 114, Node('/mdPSqf')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], ['lr', 145, Node('/lr')], ['bAUIMDVjhgcu', 162, Node('/bAUIMDVjhgcu')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# p.n
# |-- p.
# |   |-- p
# |   +-- .
# +-- n
# mdPSqf
# |-- m
# +-- dPSqf
#     |-- d
#     +-- PSqf
#         |-- PSq
#         |   |-- PS
#         |   |   |-- P
#         |   |   +-- S
#         |   +-- q
#         +-- f
# lr
# |-- l
# +-- r
# bAUIMDVjhgcu
# |-- bAUIMDVjhgc
# |   |-- bAUIMDVjhg
# |   |   |-- bAUIM
# |   |   |   |-- b
# |   |   |   +-- AUIM
# |   |   |       |-- AU
# |   |   |       |   |-- A
# |   |   |       |   +-- U
# |   |   |       +-- IM
# |   |   |           |-- I
# |   |   |           +-- M
# |   |   +-- DVjhg
# |   |       |-- DVjh
# |   |       |   |-- DVj
# |   |       |   |   |-- D
# |   |       |   |   +-- Vj
# |   |       |   |       |-- V
# |   |       |   |       +-- j
# |   |       |   +-- h
# |   |       +-- g
# |   +-- c
# +-- u
# so,NQCxv
# |-- s
# +-- o,NQCxv
#     |-- o
#     +-- ,NQCxv
#         |-- ,
#         +-- NQCxv
#             |-- NQCx
#             |   |-- N
#             |   +-- QCx
#             |       |-- QC
#             |       |   |-- Q
#             |       |   +-- C
#             |       +-- x
#             +-- v
# [['t', 91, Node('/t')], ['p.n', 97, Node('/p.n')], ['a', 102, Node('/a')], ['mdPSqf', 114, Node('/mdPSqf')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], ['lr', 145, Node('/lr')], ['bAUIMDVjhgcu', 162, Node('/bAUIMDVjhgcu')], ['so,NQCxv', 175, Node('/so,NQCxv')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# mdPSqf
# |-- m
# +-- dPSqf
#     |-- d
#     +-- PSqf
#         |-- PSq
#         |   |-- PS
#         |   |   |-- P
#         |   |   +-- S
#         |   +-- q
#         +-- f
# lr
# |-- l
# +-- r
# bAUIMDVjhgcu
# |-- bAUIMDVjhgc
# |   |-- bAUIMDVjhg
# |   |   |-- bAUIM
# |   |   |   |-- b
# |   |   |   +-- AUIM
# |   |   |       |-- AU
# |   |   |       |   |-- A
# |   |   |       |   +-- U
# |   |   |       +-- IM
# |   |   |           |-- I
# |   |   |           +-- M
# |   |   +-- DVjhg
# |   |       |-- DVjh
# |   |       |   |-- DVj
# |   |       |   |   |-- D
# |   |       |   |   +-- Vj
# |   |       |   |       |-- V
# |   |       |   |       +-- j
# |   |       |   +-- h
# |   |       +-- g
# |   +-- c
# +-- u
# so,NQCxv
# |-- s
# +-- o,NQCxv
#     |-- o
#     +-- ,NQCxv
#         |-- ,
#         +-- NQCxv
#             |-- NQCx
#             |   |-- N
#             |   +-- QCx
#             |       |-- QC
#             |       |   |-- Q
#             |       |   +-- C
#             |       +-- x
#             +-- v
# tp.n
# |-- t
# +-- p.n
#     |-- p.
#     |   |-- p
#     |   +-- .
#     +-- n
# [['a', 102, Node('/a')], ['mdPSqf', 114, Node('/mdPSqf')], ['e', 119, Node('/e')], ['i', 124, Node('/i')], ['lr', 145, Node('/lr')], ['bAUIMDVjhgcu', 162, Node('/bAUIMDVjhgcu')], ['so,NQCxv', 175, Node('/so,NQCxv')], ['tp.n', 188, Node('/tp.n')], [' ', 204, Node('/ ')]]
#
# Arbre actuel:
#
#
# lr
# |-- l
# +-- r
# bAUIMDVjhgcu
# |-- bAUIMDVjhgc
# |   |-- bAUIMDVjhg
# |   |   |-- bAUIM
# |   |   |   |-- b
# |   |   |   +-- AUIM
# |   |   |       |-- AU
# |   |   |       |   |-- A
# |   |   |       |   +-- U
# |   |   |       +-- IM
# |   |   |           |-- I
# |   |   |           +-- M
# |   |   +-- DVjhg
# |   |       |-- DVjh
# |   |       |   |-- DVj
# |   |       |   |   |-- D
# |   |       |   |   +-- Vj
# |   |       |   |       |-- V
# |   |       |   |       +-- j
# |   |       |   +-- h
# |   |       +-- g
# |   +-- c
# +-- u
# so,NQCxv
# |-- s
# +-- o,NQCxv
#     |-- o
#     +-- ,NQCxv
#         |-- ,
#         +-- NQCxv
#             |-- NQCx
#             |   |-- N
#             |   +-- QCx
#             |       |-- QC
#             |       |   |-- Q
#             |       |   +-- C
#             |       +-- x
#             +-- v
# tp.n
# |-- t
# +-- p.n
#     |-- p.
#     |   |-- p
#     |   +-- .
#     +-- n
# amdPSqf
# |-- a
# +-- mdPSqf
#     |-- m
#     +-- dPSqf
#         |-- d
#         +-- PSqf
#             |-- PSq
#             |   |-- PS
#             |   |   |-- P
#             |   |   +-- S
#             |   +-- q
#             +-- f
# [['e', 119, Node('/e')], ['i', 124, Node('/i')], ['lr', 145, Node('/lr')], ['bAUIMDVjhgcu', 162, Node('/bAUIMDVjhgcu')], ['so,NQCxv', 175, Node('/so,NQCxv')], ['tp.n', 188, Node('/tp.n')], [' ', 204, Node('/ ')], ['amdPSqf', 216, Node('/amdPSqf')]]
#
# Arbre actuel:
#
#
# lr
# |-- l
# +-- r
# bAUIMDVjhgcu
# |-- bAUIMDVjhgc
# |   |-- bAUIMDVjhg
# |   |   |-- bAUIM
# |   |   |   |-- b
# |   |   |   +-- AUIM
# |   |   |       |-- AU
# |   |   |       |   |-- A
# |   |   |       |   +-- U
# |   |   |       +-- IM
# |   |   |           |-- I
# |   |   |           +-- M
# |   |   +-- DVjhg
# |   |       |-- DVjh
# |   |       |   |-- DVj
# |   |       |   |   |-- D
# |   |       |   |   +-- Vj
# |   |       |   |       |-- V
# |   |       |   |       +-- j
# |   |       |   +-- h
# |   |       +-- g
# |   +-- c
# +-- u
# so,NQCxv
# |-- s
# +-- o,NQCxv
#     |-- o
#     +-- ,NQCxv
#         |-- ,
#         +-- NQCxv
#             |-- NQCx
#             |   |-- N
#             |   +-- QCx
#             |       |-- QC
#             |       |   |-- Q
#             |       |   +-- C
#             |       +-- x
#             +-- v
# tp.n
# |-- t
# +-- p.n
#     |-- p.
#     |   |-- p
#     |   +-- .
#     +-- n
# amdPSqf
# |-- a
# +-- mdPSqf
#     |-- m
#     +-- dPSqf
#         |-- d
#         +-- PSqf
#             |-- PSq
#             |   |-- PS
#             |   |   |-- P
#             |   |   +-- S
#             |   +-- q
#             +-- f
# ei
# |-- e
# +-- i
# [['lr', 145, Node('/lr')], ['bAUIMDVjhgcu', 162, Node('/bAUIMDVjhgcu')], ['so,NQCxv', 175, Node('/so,NQCxv')], ['tp.n', 188, Node('/tp.n')], [' ', 204, Node('/ ')], ['amdPSqf', 216, Node('/amdPSqf')], ['ei', 243, Node('/ei')]]
#
# Arbre actuel:
#
#
# so,NQCxv
# |-- s
# +-- o,NQCxv
#     |-- o
#     +-- ,NQCxv
#         |-- ,
#         +-- NQCxv
#             |-- NQCx
#             |   |-- N
#             |   +-- QCx
#             |       |-- QC
#             |       |   |-- Q
#             |       |   +-- C
#             |       +-- x
#             +-- v
# tp.n
# |-- t
# +-- p.n
#     |-- p.
#     |   |-- p
#     |   +-- .
#     +-- n
# amdPSqf
# |-- a
# +-- mdPSqf
#     |-- m
#     +-- dPSqf
#         |-- d
#         +-- PSqf
#             |-- PSq
#             |   |-- PS
#             |   |   |-- P
#             |   |   +-- S
#             |   +-- q
#             +-- f
# ei
# |-- e
# +-- i
# lrbAUIMDVjhgcu
# |-- lr
# |   |-- l
# |   +-- r
# +-- bAUIMDVjhgcu
#     |-- bAUIMDVjhgc
#     |   |-- bAUIMDVjhg
#     |   |   |-- bAUIM
#     |   |   |   |-- b
#     |   |   |   +-- AUIM
#     |   |   |       |-- AU
#     |   |   |       |   |-- A
#     |   |   |       |   +-- U
#     |   |   |       +-- IM
#     |   |   |           |-- I
#     |   |   |           +-- M
#     |   |   +-- DVjhg
#     |   |       |-- DVjh
#     |   |       |   |-- DVj
#     |   |       |   |   |-- D
#     |   |       |   |   +-- Vj
#     |   |       |   |       |-- V
#     |   |       |   |       +-- j
#     |   |       |   +-- h
#     |   |       +-- g
#     |   +-- c
#     +-- u
# [['so,NQCxv', 175, Node('/so,NQCxv')], ['tp.n', 188, Node('/tp.n')], [' ', 204, Node('/ ')], ['amdPSqf', 216, Node('/amdPSqf')], ['ei', 243, Node('/ei')], ['lrbAUIMDVjhgcu', 307, Node('/lrbAUIMDVjhgcu')]]
#
# Arbre actuel:
#
#
# amdPSqf
# |-- a
# +-- mdPSqf
#     |-- m
#     +-- dPSqf
#         |-- d
#         +-- PSqf
#             |-- PSq
#             |   |-- PS
#             |   |   |-- P
#             |   |   +-- S
#             |   +-- q
#             +-- f
# ei
# |-- e
# +-- i
# lrbAUIMDVjhgcu
# |-- lr
# |   |-- l
# |   +-- r
# +-- bAUIMDVjhgcu
#     |-- bAUIMDVjhgc
#     |   |-- bAUIMDVjhg
#     |   |   |-- bAUIM
#     |   |   |   |-- b
#     |   |   |   +-- AUIM
#     |   |   |       |-- AU
#     |   |   |       |   |-- A
#     |   |   |       |   +-- U
#     |   |   |       +-- IM
#     |   |   |           |-- I
#     |   |   |           +-- M
#     |   |   +-- DVjhg
#     |   |       |-- DVjh
#     |   |       |   |-- DVj
#     |   |       |   |   |-- D
#     |   |       |   |   +-- Vj
#     |   |       |   |       |-- V
#     |   |       |   |       +-- j
#     |   |       |   +-- h
#     |   |       +-- g
#     |   +-- c
#     +-- u
# so,NQCxvtp.n
# |-- so,NQCxv
# |   |-- s
# |   +-- o,NQCxv
# |       |-- o
# |       +-- ,NQCxv
# |           |-- ,
# |           +-- NQCxv
# |               |-- NQCx
# |               |   |-- N
# |               |   +-- QCx
# |               |       |-- QC
# |               |       |   |-- Q
# |               |       |   +-- C
# |               |       +-- x
# |               +-- v
# +-- tp.n
#     |-- t
#     +-- p.n
#         |-- p.
#         |   |-- p
#         |   +-- .
#         +-- n
# [[' ', 204, Node('/ ')], ['amdPSqf', 216, Node('/amdPSqf')], ['ei', 243, Node('/ei')], ['lrbAUIMDVjhgcu', 307, Node('/lrbAUIMDVjhgcu')], ['so,NQCxvtp.n', 363, Node('/so,NQCxvtp.n')]]
#
# Arbre actuel:
#
#
# ei
# |-- e
# +-- i
# lrbAUIMDVjhgcu
# |-- lr
# |   |-- l
# |   +-- r
# +-- bAUIMDVjhgcu
#     |-- bAUIMDVjhgc
#     |   |-- bAUIMDVjhg
#     |   |   |-- bAUIM
#     |   |   |   |-- b
#     |   |   |   +-- AUIM
#     |   |   |       |-- AU
#     |   |   |       |   |-- A
#     |   |   |       |   +-- U
#     |   |   |       +-- IM
#     |   |   |           |-- I
#     |   |   |           +-- M
#     |   |   +-- DVjhg
#     |   |       |-- DVjh
#     |   |       |   |-- DVj
#     |   |       |   |   |-- D
#     |   |       |   |   +-- Vj
#     |   |       |   |       |-- V
#     |   |       |   |       +-- j
#     |   |       |   +-- h
#     |   |       +-- g
#     |   +-- c
#     +-- u
# so,NQCxvtp.n
# |-- so,NQCxv
# |   |-- s
# |   +-- o,NQCxv
# |       |-- o
# |       +-- ,NQCxv
# |           |-- ,
# |           +-- NQCxv
# |               |-- NQCx
# |               |   |-- N
# |               |   +-- QCx
# |               |       |-- QC
# |               |       |   |-- Q
# |               |       |   +-- C
# |               |       +-- x
# |               +-- v
# +-- tp.n
#     |-- t
#     +-- p.n
#         |-- p.
#         |   |-- p
#         |   +-- .
#         +-- n
#  amdPSqf
# |--
# +-- amdPSqf
#     |-- a
#     +-- mdPSqf
#         |-- m
#         +-- dPSqf
#             |-- d
#             +-- PSqf
#                 |-- PSq
#                 |   |-- PS
#                 |   |   |-- P
#                 |   |   +-- S
#                 |   +-- q
#                 +-- f
# [['ei', 243, Node('/ei')], ['lrbAUIMDVjhgcu', 307, Node('/lrbAUIMDVjhgcu')], ['so,NQCxvtp.n', 363, Node('/so,NQCxvtp.n')], [' amdPSqf', 420, Node('/ amdPSqf')]]
#
# Arbre actuel:
#
#
# so,NQCxvtp.n
# |-- so,NQCxv
# |   |-- s
# |   +-- o,NQCxv
# |       |-- o
# |       +-- ,NQCxv
# |           |-- ,
# |           +-- NQCxv
# |               |-- NQCx
# |               |   |-- N
# |               |   +-- QCx
# |               |       |-- QC
# |               |       |   |-- Q
# |               |       |   +-- C
# |               |       +-- x
# |               +-- v
# +-- tp.n
#     |-- t
#     +-- p.n
#         |-- p.
#         |   |-- p
#         |   +-- .
#         +-- n
#  amdPSqf
# |--
# +-- amdPSqf
#     |-- a
#     +-- mdPSqf
#         |-- m
#         +-- dPSqf
#             |-- d
#             +-- PSqf
#                 |-- PSq
#                 |   |-- PS
#                 |   |   |-- P
#                 |   |   +-- S
#                 |   +-- q
#                 +-- f
# eilrbAUIMDVjhgcu
# |-- ei
# |   |-- e
# |   +-- i
# +-- lrbAUIMDVjhgcu
#     |-- lr
#     |   |-- l
#     |   +-- r
#     +-- bAUIMDVjhgcu
#         |-- bAUIMDVjhgc
#         |   |-- bAUIMDVjhg
#         |   |   |-- bAUIM
#         |   |   |   |-- b
#         |   |   |   +-- AUIM
#         |   |   |       |-- AU
#         |   |   |       |   |-- A
#         |   |   |       |   +-- U
#         |   |   |       +-- IM
#         |   |   |           |-- I
#         |   |   |           +-- M
#         |   |   +-- DVjhg
#         |   |       |-- DVjh
#         |   |       |   |-- DVj
#         |   |       |   |   |-- D
#         |   |       |   |   +-- Vj
#         |   |       |   |       |-- V
#         |   |       |   |       +-- j
#         |   |       |   +-- h
#         |   |       +-- g
#         |   +-- c
#         +-- u
# [['so,NQCxvtp.n', 363, Node('/so,NQCxvtp.n')], [' amdPSqf', 420, Node('/ amdPSqf')], ['eilrbAUIMDVjhgcu', 550, Node('/eilrbAUIMDVjhgcu')]]
#
# Arbre actuel:
#
#
# eilrbAUIMDVjhgcu
# |-- ei
# |   |-- e
# |   +-- i
# +-- lrbAUIMDVjhgcu
#     |-- lr
#     |   |-- l
#     |   +-- r
#     +-- bAUIMDVjhgcu
#         |-- bAUIMDVjhgc
#         |   |-- bAUIMDVjhg
#         |   |   |-- bAUIM
#         |   |   |   |-- b
#         |   |   |   +-- AUIM
#         |   |   |       |-- AU
#         |   |   |       |   |-- A
#         |   |   |       |   +-- U
#         |   |   |       +-- IM
#         |   |   |           |-- I
#         |   |   |           +-- M
#         |   |   +-- DVjhg
#         |   |       |-- DVjh
#         |   |       |   |-- DVj
#         |   |       |   |   |-- D
#         |   |       |   |   +-- Vj
#         |   |       |   |       |-- V
#         |   |       |   |       +-- j
#         |   |       |   +-- h
#         |   |       +-- g
#         |   +-- c
#         +-- u
# so,NQCxvtp.n amdPSqf
# |-- so,NQCxvtp.n
# |   |-- so,NQCxv
# |   |   |-- s
# |   |   +-- o,NQCxv
# |   |       |-- o
# |   |       +-- ,NQCxv
# |   |           |-- ,
# |   |           +-- NQCxv
# |   |               |-- NQCx
# |   |               |   |-- N
# |   |               |   +-- QCx
# |   |               |       |-- QC
# |   |               |       |   |-- Q
# |   |               |       |   +-- C
# |   |               |       +-- x
# |   |               +-- v
# |   +-- tp.n
# |       |-- t
# |       +-- p.n
# |           |-- p.
# |           |   |-- p
# |           |   +-- .
# |           +-- n
# +--  amdPSqf
#     |--
#     +-- amdPSqf
#         |-- a
#         +-- mdPSqf
#             |-- m
#             +-- dPSqf
#                 |-- d
#                 +-- PSqf
#                     |-- PSq
#                     |   |-- PS
#                     |   |   |-- P
#                     |   |   +-- S
#                     |   +-- q
#                     +-- f
# [['eilrbAUIMDVjhgcu', 550, Node('/eilrbAUIMDVjhgcu')], ['so,NQCxvtp.n amdPSqf', 783, Node('/so,NQCxvtp.n amdPSqf')]]
#
# Arbre actuel:
#
#
# eilrbAUIMDVjhgcuso,NQCxvtp.n amdPSqf
# |-- eilrbAUIMDVjhgcu
# |   |-- ei
# |   |   |-- e
# |   |   +-- i
# |   +-- lrbAUIMDVjhgcu
# |       |-- lr
# |       |   |-- l
# |       |   +-- r
# |       +-- bAUIMDVjhgcu
# |           |-- bAUIMDVjhgc
# |           |   |-- bAUIMDVjhg
# |           |   |   |-- bAUIM
# |           |   |   |   |-- b
# |           |   |   |   +-- AUIM
# |           |   |   |       |-- AU
# |           |   |   |       |   |-- A
# |           |   |   |       |   +-- U
# |           |   |   |       +-- IM
# |           |   |   |           |-- I
# |           |   |   |           +-- M
# |           |   |   +-- DVjhg
# |           |   |       |-- DVjh
# |           |   |       |   |-- DVj
# |           |   |       |   |   |-- D
# |           |   |       |   |   +-- Vj
# |           |   |       |   |       |-- V
# |           |   |       |   |       +-- j
# |           |   |       |   +-- h
# |           |   |       +-- g
# |           |   +-- c
# |           +-- u
# +-- so,NQCxvtp.n amdPSqf
#     |-- so,NQCxvtp.n
#     |   |-- so,NQCxv
#     |   |   |-- s
#     |   |   +-- o,NQCxv
#     |   |       |-- o
#     |   |       +-- ,NQCxv
#     |   |           |-- ,
#     |   |           +-- NQCxv
#     |   |               |-- NQCx
#     |   |               |   |-- N
#     |   |               |   +-- QCx
#     |   |               |       |-- QC
#     |   |               |       |   |-- Q
#     |   |               |       |   +-- C
#     |   |               |       +-- x
#     |   |               +-- v
#     |   +-- tp.n
#     |       |-- t
#     |       +-- p.n
#     |           |-- p.
#     |           |   |-- p
#     |           |   +-- .
#     |           +-- n
#     +--  amdPSqf
#         |--
#         +-- amdPSqf
#             |-- a
#             +-- mdPSqf
#                 |-- m
#                 +-- dPSqf
#                     |-- d
#                     +-- PSqf
#                         |-- PSq
#                         |   |-- PS
#                         |   |   |-- P
#                         |   |   +-- S
#                         |   +-- q
#                         +-- f
# [['eilrbAUIMDVjhgcuso,NQCxvtp.n amdPSqf', 1333, Node('/eilrbAUIMDVjhgcuso,NQCxvtp.n amdPSqf')]]

# %%
ArbreCodes = Node('')
noeud = ArbreCodes
#print([node.name for node in PreOrderIter(ArbreSymb[0][2])])
parcoursprefix = [node for node in PreOrderIter(ArbreSymb[0][2])]
parcoursprefix = parcoursprefix[1:len(parcoursprefix)] #ignore la racine

Prevdepth = 0 #pour suivre les mouvements en profondeur dans l'arbre
for node in parcoursprefix:  #Liste des noeuds
    if Prevdepth < node.depth: #On va plus profond dans l'arbre, on met un 0
        temp = Node(noeud.name + '0')
        noeud.children = [temp]
        if node.children: #On avance le "pointeur" noeud si le noeud ajouté a des enfants.
            noeud = temp
    elif Prevdepth == node.depth: #Même profondeur, autre feuille, on met un 1
        temp = Node(noeud.name + '1')
        noeud.children = [noeud.children[0], temp]  #Ajoute le deuxième enfant
        if node.children: #On avance le "pointeur" noeud si le noeud ajouté a des enfants.
            noeud = temp
    else:
        for i in range(Prevdepth-node.depth): #On prend une autre branche, donc on met un 1
            noeud = noeud.parent #On remontre dans l'arbre pour prendre la prochaine branche non explorée.
        temp = Node(noeud.name + '1')
        noeud.children = [noeud.children[0], temp]
        if node.children:
            noeud = temp

    Prevdepth = node.depth

print('\nArbre des codes:\n\n',RenderTree(ArbreCodes, style=AsciiStyle()).by_attr())
print('\nArbre des symboles:\n\n', RenderTree(ArbreSymb[0][2], style=AsciiStyle()).by_attr())
# Out:
# Arbre des codes:
#
#
# |-- 0
# |   |-- 00
# |   |   |-- 000
# |   |   +-- 001
# |   +-- 01
# |       |-- 010
# |       |   |-- 0100
# |       |   +-- 0101
# |       +-- 011
# |           |-- 0110
# |           |   |-- 01100
# |           |   |   |-- 011000
# |           |   |   |   |-- 0110000
# |           |   |   |   +-- 0110001
# |           |   |   |       |-- 01100010
# |           |   |   |       |   |-- 011000100
# |           |   |   |       |   +-- 011000101
# |           |   |   |       +-- 01100011
# |           |   |   |           |-- 011000110
# |           |   |   |           +-- 011000111
# |           |   |   +-- 011001
# |           |   |       |-- 0110010
# |           |   |       |   |-- 01100100
# |           |   |       |   |   |-- 011001000
# |           |   |       |   |   +-- 011001001
# |           |   |       |   |       |-- 0110010010
# |           |   |       |   |       +-- 0110010011
# |           |   |       |   +-- 01100101
# |           |   |       +-- 0110011
# |           |   +-- 01101
# |           +-- 0111
# +-- 1
#     |-- 10
#     |   |-- 100
#     |   |   |-- 1000
#     |   |   +-- 1001
#     |   |       |-- 10010
#     |   |       +-- 10011
#     |   |           |-- 100110
#     |   |           +-- 100111
#     |   |               |-- 1001110
#     |   |               |   |-- 10011100
#     |   |               |   +-- 10011101
#     |   |               |       |-- 100111010
#     |   |               |       |   |-- 1001110100
#     |   |               |       |   +-- 1001110101
#     |   |               |       +-- 100111011
#     |   |               +-- 1001111
#     |   +-- 101
#     |       |-- 1010
#     |       +-- 1011
#     |           |-- 10110
#     |           |   |-- 101100
#     |           |   +-- 101101
#     |           +-- 10111
#     +-- 11
#         |-- 110
#         +-- 111
#             |-- 1110
#             +-- 1111
#                 |-- 11110
#                 +-- 11111
#                     |-- 111110
#                     +-- 111111
#                         |-- 1111110
#                         |   |-- 11111100
#                         |   |   |-- 111111000
#                         |   |   +-- 111111001
#                         |   +-- 11111101
#                         +-- 1111111
#
# Arbre des symboles:
#
#  eilrbAUIMDVjhgcuso,NQCxvtp.n amdPSqf
# |-- eilrbAUIMDVjhgcu
# |   |-- ei
# |   |   |-- e
# |   |   +-- i
# |   +-- lrbAUIMDVjhgcu
# |       |-- lr
# |       |   |-- l
# |       |   +-- r
# |       +-- bAUIMDVjhgcu
# |           |-- bAUIMDVjhgc
# |           |   |-- bAUIMDVjhg
# |           |   |   |-- bAUIM
# |           |   |   |   |-- b
# |           |   |   |   +-- AUIM
# |           |   |   |       |-- AU
# |           |   |   |       |   |-- A
# |           |   |   |       |   +-- U
# |           |   |   |       +-- IM
# |           |   |   |           |-- I
# |           |   |   |           +-- M
# |           |   |   +-- DVjhg
# |           |   |       |-- DVjh
# |           |   |       |   |-- DVj
# |           |   |       |   |   |-- D
# |           |   |       |   |   +-- Vj
# |           |   |       |   |       |-- V
# |           |   |       |   |       +-- j
# |           |   |       |   +-- h
# |           |   |       +-- g
# |           |   +-- c
# |           +-- u
# +-- so,NQCxvtp.n amdPSqf
#     |-- so,NQCxvtp.n
#     |   |-- so,NQCxv
#     |   |   |-- s
#     |   |   +-- o,NQCxv
#     |   |       |-- o
#     |   |       +-- ,NQCxv
#     |   |           |-- ,
#     |   |           +-- NQCxv
#     |   |               |-- NQCx
#     |   |               |   |-- N
#     |   |               |   +-- QCx
#     |   |               |       |-- QC
#     |   |               |       |   |-- Q
#     |   |               |       |   +-- C
#     |   |               |       +-- x
#     |   |               +-- v
#     |   +-- tp.n
#     |       |-- t
#     |       +-- p.n
#     |           |-- p.
#     |           |   |-- p
#     |           |   +-- .
#     |           +-- n
#     +--  amdPSqf
#         |--
#         +-- amdPSqf
#             |-- a
#             +-- mdPSqf
#                 |-- m
#                 +-- dPSqf
#                     |-- d
#                     +-- PSqf
#                         |-- PSq
#                         |   |-- PS
#                         |   |   |-- P
#                         |   |   +-- S
#                         |   +-- q
#                         +-- f

# %%
ArbreSymbList = [node for node in PreOrderIter(ArbreSymb[0][2])]
ArbreCodeList = [node for node in PreOrderIter(ArbreCodes)]

for i in range(len(ArbreSymbList)):
    if ArbreSymbList[i].is_leaf: #Génère des codes pour les feuilles seulement
        temp = list(filter(lambda x: x[0] == ArbreSymbList[i].name, dictionnaire))
        if temp:
            indice = dictionnaire.index(temp[0])
            dictionnaire[indice][1] = ArbreCodeList[i].name

print(dictionnaire)
# Out:
# [['A', '011000100'], ['l', '0100'], ['i', '001'], ['q', '11111101'], ['u', '0111'], ['a', '1110'], ['m', '11110'], [' ', '110'], ['p', '101100'], ['c', '01101'], ['e', '000'], ['r', '0101'], ['t', '1010'], ['d', '111110'], ['s', '1000'], ['v', '1001111'], ['n', '10111'], ['.', '101101'], ['V', '0110010010'], ['b', '0110000'], [',', '100110'], ['o', '10010'], ['x', '100111011'], ['P', '111111000'], ['U', '011000101'], ['f', '1111111'], ['S', '111111001'], ['h', '01100101'], ['N', '10011100'], ['g', '0110011'], ['I', '011000110'], ['M', '011000111'], ['j', '0110010011'], ['Q', '1001110100'], ['D', '011001000'], ['C', '1001110101']]

# %%
MessageCode = []
longueur = 0
for i in range(len(Message)):
    substitution = list(filter(lambda x: x[0] == Message[i], dictionnaire))
    MessageCode += [substitution[0][1]]
    longueur += len(substitution[0][1])
print(MessageCode)
# Out:
# ['011000100', '0100', '001', '11111101', '0111', '1110', '11110', '110', '101100', '0100', '1110', '01101', '000', '0101', '1110', '1010', '110', '111110', '001', '01101', '1010', '0111', '11110', '110', '0100', '000', '01101', '1010', '0111', '1000', '110', '1001111', '000', '0100', '110', '101100', '000', '0100', '0100', '000', '10111', '1010', '000', '1000', '11111101', '0111', '000', '101101', '110', '0110010010', '000', '1000', '1010', '001', '0110000', '0111', '0100', '0111', '11110', '110', '1000', '000', '11110', '101100', '000', '0101', '110', '111110', '0111', '001', '110', '0100', '1110', '01101', '0111', '1000', '100110', '110', '1000', '000', '111110', '110', '01101', '10010', '11110', '11110', '10010', '111110', '10010', '110', '111110', '10010', '0100', '10010', '0101', '110', '11110', '1110', '100111011', '001', '11110', '0111', '1000', '110', '1110', '101101', '110', '111111000', '0101', '1110', '000', '1000', '000', '10111', '1010', '110', '01101', '10010', '10111', '1001111', '1110', '0100', '0100', '001', '1000', '110', '001', '10111', '110', '11111101', '0111', '1110', '11110', '110', '001', '10111', '110', '101100', '10010', '1000', '0111', '000', '0101', '000', '101101', '110', '011000101', '1010', '110', '000', '0100', '000', '001', '1111111', '000', '10111', '111110', '110', '1010', '10010', '0101', '1010', '10010', '0101', '110', '1110', '110', '0100', '1110', '10010', '0101', '000', '000', '1010', '110', '001', '11110', '101100', '000', '0101', '111110', '001', '000', '1010', '101101', '110', '111111001', '000', '111110', '110', '101100', '01100101', '1110', '0101', '000', '1010', '0101', '1110', '110', '0101', '001', '1000', '0111', '1000', '110', '1000', '001', '1010', '110', '1110', '11110', '000', '1010', '110', '1001111', '000', '0100', '001', '1010', '110', '01101', '0111', '0101', '1000', '0111', '1000', '110', '1000', '000', '11110', '101100', '000', '0101', '101101', '110', '10011100', '1110', '11110', '110', '01101', '10010', '10111', '0110011', '0111', '000', '110', '1110', '01101', '110', '0100', '000', '01101', '1010', '0111', '1000', '110', '1000', '001', '1010', '110', '1110', '11110', '000', '1010', '110', '0100', '1110', '10010', '0101', '000', '000', '1010', '101101', '110', '011000110', '10111', '1010', '000', '0110011', '000', '0101', '110', '11111101', '0111', '001', '1000', '110', '0100', '1110', '01101', '001', '10111', '001', '1110', '110', '1010', '0111', '0101', '101100', '001', '1000', '101101', '110', '011000111', '1110', '000', '01101', '000', '10111', '1110', '1000', '110', '000', '0101', '1110', '1010', '110', '10010', '0101', '01101', '001', '100110', '110', '101100', '10010', '0101', '1010', '1010', '001', '1010', '10010', '0101', '110', '1110', '01101', '110', '0100', '001', '0110011', '0111', '0100', '1110', '110', '111110', '1110', '101100', '001', '0110000', '0111', '1000', '100110', '110', '001', '10111', '1010', '000', '0101', '111110', '0111', '11110', '110', '1111111', '0101', '001', '10111', '0110011', '001', '0100', '0100', '1110', '110', '10111', '0111', '10111', '01101', '101101', '110', '111111000', '0101', '10010', '001', '10111', '110', '1110', '0111', '01101', '1010', '10010', '0101', '100110', '110', '1110', '0101', '01101', '0111', '110', '1110', '01101', '110', '1111111', '000', '0101', '11110', '000', '10111', '1010', '0111', '11110', '110', '0111', '0100', '1010', '0101', '001', '01101', '001', '000', '1000', '100110', '110', '000', '0101', '1110', '1010', '110', '0110010011', '0111', '1000', '1010', '10010', '110', '0100', '1110', '10010', '0101', '000', '000', '1010', '110', '10111', '0111', '10111', '01101', '100110', '110', '1000', '001', '1010', '110', '1110', '11110', '000', '1010', '110', '0100', '1110', '01101', '001', '10111', '001', '1110', '110', '0100', '10010', '0101', '000', '11110', '110', '000', '0100', '001', '1010', '110', '1001111', '000', '0100', '110', '111110', '10010', '0100', '10010', '0101', '101101', '110', '011000100', ' ...

# %%
print("Longueur = {0}".format(longueur))
print("Longueur originale = {0}".format(longueurOriginale))
print("Ratio = {0}".format(longueur/longueurOriginale))
# Out:
# Longueur = 5601
# Longueur originale = 7998.0
# Ratio = 0.7003000750187547

# %%
print('Espérance: ' + str(longueur/len(Message)))
entropie =0
for i in range(nbsymboles):
  entropie = entropie-(OccSymb[i][1]/len(Message))*math.log(OccSymb[i][1]/len(Message),2)

print('Entropie: ' + str(entropie))
# Out:
# Espérance: 4.201800450112528
# Entropie: 4.170085812310875
